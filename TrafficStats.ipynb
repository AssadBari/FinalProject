# %%
plt.figure(figsize=(10, 12))
sns.barplot(data=avg_traffic, y="neighborhood", x="average_daily_car_traffic", palette="viridis")
plt.title('Average Traffic by Neighborhood', fontsize=14)
plt.xlabel('Average Daily Car Traffic', fontsize=12)
plt.ylabel('Neighborhood', fontsize=12)
plt.tight_layout()
plt.show()
